# %%
import googleapiclient.discovery
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyAJHdUHbT_76mAjD5swArV1PRygzWtosv4"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="d1O2TnjiA5g",
    maxResults=100
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# Ok but hydrogen can explode what about safety
# Everything keeps going Right - Toyota
# It doesn&#39;t matter what type of engine you come up with . The western countries will shut it down. They are not interested in better products even if it&#39;s &quot;clean energy&quot;. They simply don&#39;t want you to drive , to be stationary or within a certain distance of home and control you, your family and friends movement.. that&#39;s all.<br>It&#39;s not about the religion of &quot;climate change&quot;.
# Good job sir ji 👍
# Electric cars are an unsustainable scam there’s not enough cobalt to make batteries 🪫
# it cost like $170 bucks to refill to get u 200 miles of range
# Hydrogen tank is nothing but a bomb. They have to fix this problem.
# If they wanna reduce carbon, you need more trees. Not cutting down trees. Have you noticed? It&#39;s gotten warmer the past 20 years because of stupid people that won a cut down trees because it disrupts the look of their house of view, and then others that just my acres of land tear down acres of trees to put up condos. Something that we don&#39;t need in a densely populated area.
# Yes Toyota is the best but....only changes in Hydrogen power. What about those mechanical parts that are still intact. As compared to EV, there are so many mechanical parts that no longer used in EV. That is saving plus environment protection...
# It will only work in Japan because of the government support in building these expensive hydrogen stations/kiosks. Just ask the US government to come up funds to build these kiosks all over USA, no chance at all! It wouldn&#39;t happen in other countries as well, mainly due to cost/challenge of transportation &amp; storage of hydrogen. Japan government has to support its own car industry, mainly the top 2 car manufacturers, Toyota &amp; Honda. Japan has no other choice as they have already lag behind US, China, Korea &amp; other countries in the EV technology. They can blow whatever wind they have for hydrogen engine but it will not take off in many countries especially the big car markets in the US &amp; China or even India (even poorer in infrastructures). Japan should just be happy with this usage in their own market whereas the world is moving forward with EVs. I personally think that the Japanese car manufacturers have bet on the wrong technology and time will tell whether these giants will fall. A good example is Kodak when they pushed so hard for Polaroid when film technology has moved on to digital. Another example is Nokia or Ericson when they didn&#39;t see that the world is moving towards smart phone.
# Yes it is proven that Japanese feel Chinese n Korean as their enemies...haha
# If it&#39;s not gas then I&#39;m straight.
# Fire make carbon monoxide went its burn air
# The issue will hydrogen engines isn’t the engine’s capability, it is the issues with hydrogen storage, embrittlement and range.  If/when industry can effectively fix these issues hydrogen will be viable.  I don’t expect that it will be viable as a family vehicle fuel any time soon.  Big Fossil Fuels keep trying to be relevant to no avail.
# Where can I buy one?
# Almost Perfect machine😊
# How are these engines made?? I bet it is not green technology 😢😢
# Hydrogen maybe in 2040 but not now
# Really, I hope they reach.
# there was a guy who invented his own car to run on hydrogen years ago.. he went missing
# Ethanol is the future! Clean, easy, safe and generate a lot of jobs.
# yes
# Another explanation why in the future only rich and chosen will be able to drive their vehicles and the rest of us will be on bicycles
# Well actually considering water vapour is much bigger effect the co2 on global warming not sure how this will help
# At the end of the day I would much rather take an electric vehicle over hydrogen, thousands of parts to run a hydrogen motor where as an electric vehicle has very few parts just like a radio controlled toy car.<br><br>Let&#39;s not forget that supply and demand will spike refueling cost for this technological breakthrough marvel lol!!!
# Id rather have an electric car.   internal combustion engines are Rube Goldberg machines.
# The Japanese have already been punished once by the globalists with Fukushima for their ideas with hydrogen. I don&#39;t know the reason why engines using LPG or CNG as base fuel are not produced. Kia did a little work on that development. LPG and CNG are much less polluting, give a lot of power, and the existing engine does not need to be modified much.
# They just can&#39;t compete in EVs. Period.
# My only concern about Hydrogen powered cars is, what happens if that fuel cell gets ruptured, would that be like a hydrogen bomb going off? if so this is dead in the water. If not, Hydrogen is far and away the best way to go.
# Where do you think they get the hydrogen?
# When an American scientist developed a magnetic motor. govenment did not allow him. becase this was against the Govt policy.
# One Pakistani  engineer who introduced this idea was kidnapped by agencies and no one know where he is and what had hapend with him.
# Fuel mafias never wants to run like this ideas.
# New problem : water vapour pollution ....too much water vapour in the  atmosphere ..creating severe thunderstorms every now and then...
# I still drive my 2005 Toyota Prius; it is going strong and has only 135,000 miles. I trust Toyota more than Elon Musk. It’s genius that Toyota would develop a Hydrogen powered auto. Toyota can develop the “Service Stations” that would fuel their new revolutionary autos; making income on their autos and fueling them.
# China now have sodium batteries which come frome the sea, even cheaper... Toyota will end up under byd brand
# Yes, look around, all the hydrogen fueling stations popping up everywhere 🙄🙄
# A highly inflammable hydrogen .
# In Pakistan 🇵🇰  this technology already comes in 2014. Our engineers make an engine who runs with water, no fuel combustion
# i have made H in 2016. but in india you cant get far because there is no support system. all thug and opportunists here.
# Every moving parts need oil.<br>Even the green hidrogen engine needs oil to lubricant the engine.
# I’d have a Hydrogen powered car before an electric powered vehicle any day! This is the way forward and Governments need to get on board immediately! Well done Toyota 🎉👌🏼👏🏼
# Honda had this tech a decade ago. They launched it in europe and failed. Lets be economic pure electricity i.e, solar and wind can be used to generate electricity to charge up a car on the go or at stand by.
# the
# It’s not a new concept, plus hydrogen is very hard to store and also really volatile, a small leak can cause massive explorations. Cant imagine how high it will be to refuel such a car
# Toyota will need to developt and sell home Hydrogen Fuel maker to make it really happen. 5 KG of Hydrogen homemade sound good. Pair it with solar power and we will have a self sustaining system.
# Even if we invented polution free petrol/diesel and we had a infiniate supply of it we need to move away from the combustion engine. Its to complicated and to many things csn break and fail, ev is a motor and a battery its only two things that can fail
# Toyota is heavily invested in electric cars with solid-state batteries. This project has been floating around for years and has gotten nowhere for a myriad of reasons.
# Toyota is the world leader in ice engines , well done Japan 🇯🇵 superior intelligence
# Biden will never let H2 burners ever happen. He is too invested in Chinese made EVs.
# But water produced can lead to corrosion of the engine. How they will protect it ?
# Turning a car into a rolling hydrogen bomb
# Hydrogen car is not new. If this is really sustainable, then at least today half of the car population is already using Fuel Cells. Problem is the $2M cost per fuel cell station plus the handling. Japan has been subsidizing these but it still the growth was a slumped but I&#39;m still hoping this in the future that all would be cheaper than petrol or EVs.
# Some how the powers that be will keep it out of the US
# what I failed to understand Why Toyota has begun to produce EV cars.
# 😂😂😂😂😂😂😂😂😂
# There are no hydrogen combustion engines used in cars. So this would be the first…if that’s what you are really talking about.
# What about the safety of Pressure &amp; Hydrogen Tanks, Collision test / Impact / Survive rate ?
# hydrogen has never address the issue for cheaper car maintenance. hydrogen powered engine are costly to maintain and composed of more parts than ICE. hydrogen are highly corrosive and flammable and difficult to store. leaks are dangerous. when caught with fire its difficult to extinguish. also hydrogen infrastructure worldwide are very limited and some facilities are already closing.
# Go Toyota go.
# the problem with hydrogen is storage. When the needed storage system is heavier than batteries- there is no point.
# Toyota is bragging😅
# 😂😂😮😮😮
# This engine sounds more appropriate for military than the proposed electric tanks.

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaS
#
#     like_count                                               text
# 0            0      Ok but hydrogen can explode what about safety
# 1            0              Everything keeps going Right - Toyota
# 2            0  It doesn&#39;t matter what type of engine you ...
# 3            0                                  Good job sir ji 👍
# 4            0  Electric cars are an unsustainable scam there’...
# ..         ...                                                ...
# 95           0                                      Go Toyota go.
# 96           1  the problem with hydrogen is storage. When the...
# 97           0                                Toyota is bragging😅
# 98           0                                              😂😂😮😮😮
# 99           0  This engine sounds more appropriate for milita...
#
# [100 rows x 5 columns]

# %%
df.tail()
# Out:
#                   author          published_at            updated_at  \
# 95      @user-iu8ex6eu9m  2024-03-31T05:16:08Z  2024-03-31T05:16:08Z
# 96     @prof.crastinator  2024-03-30T23:02:33Z  2024-03-30T23:02:33Z
# 97  @piyanutheinsang7863  2024-03-30T15:56:21Z  2024-03-30T15:56:21Z
# 98      @YouTubeforanima  2024-03-30T07:10:46Z  2024-03-30T07:10:46Z
# 99           @Khachaturr  2024-03-29T23:30:51Z  2024-03-29T23:30:51Z
#
#     like_count                                               text
# 95           0                                      Go Toyota go.
# 96           1  the problem with hydrogen is storage. When the...
# 97           0                                Toyota is bragging😅
# 98           0                                              😂😂😮😮😮
# 99           0  This engine sounds more appropriate for milita...

# %%
df.mode()
# Out:
#                      author          published_at            updated_at  \
# 0         @ZeeshanAli-js1qp  2024-03-29T23:30:51Z  2024-03-29T23:30:51Z
# 1   @acmlsrtvxacmlsrtvx3059  2024-03-30T07:10:46Z  2024-03-30T07:10:46Z
# 2                       NaN  2024-03-30T15:56:21Z  2024-03-30T15:56:21Z
# 3                       NaN  2024-03-30T23:02:33Z  2024-03-30T23:02:33Z
# 4                       NaN  2024-03-31T05:16:08Z  2024-03-31T05:16:08Z
# ..                      ...                   ...                   ...
# 95                      NaN  2024-06-22T16:55:14Z  2024-06-22T16:55:14Z
# 96                      NaN  2024-06-23T18:34:51Z  2024-06-23T18:34:51Z
# 97                      NaN  2024-06-25T21:09:36Z  2024-06-25T21:09:36Z
# 98                      NaN  2024-06-27T00:30:35Z  2024-06-27T00:30:35Z
# 99                      NaN  2024-06-29T07:20:20Z  2024-06-29T07:20:20Z
#
#     like_count                                               text
# 0          0.0  They&#39;ll still charge you for it at the hyd...
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# ..         ...                                                ...
# 95         NaN                                                NaN
# 96         NaN                                                NaN
# 97         NaN                                                NaN
# 98         NaN                                                NaN
# 99         NaN                                                NaN
#
# [100 rows x 5 columns]

# %%
df.describe()
# Out:
#        like_count
# count  100.000000
# mean     0.700000
# std      5.536837
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max     55.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   author        100 non-null    object
#  1   published_at  100 non-null    object
#  2   updated_at    100 non-null    object
#  3   like_count    100 non-null    int64
#  4   text          100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
df.isnull().sum()
# Out:
# author          0
# published_at    0
# updated_at      0
# like_count      0
# text            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
composition_value_counts = df['author'].value_counts()
composition_value_counts
# Out:
# author
# @ZeeshanAli-js1qp          3
# @acmlsrtvxacmlsrtvx3059    3
# @markiankchik1338          2
# @kevingamuna6242           2
# @deepakambati1659          1
#                           ..
# @user-pr6vv9ys8z           1
# @MrConstitutionDay         1
# @geoffclements269          1
# @disneybudgetinn3752       1
# @Khachaturr                1
# Name: count, Length: 94, dtype: int64

# %%
import matplotlib.pyplot as plt
# Bar plot of the top 10 most frequent authors
composition_value_counts.head(10).plot(kind='bar')
plt.xlabel('Author')
plt.ylabel('Count')
plt.title('Top 10 Most Frequent Authors')
plt.show()

# %%
# Pie chart of the top 5 most frequent authors
composition_value_counts.head(5).plot(kind='pie', autopct='%1.1f%%')
plt.title('Top 5 Most Frequent Authors')
plt.show()

# %%
import matplotlib.pyplot as plt

df_sorted = df.sort_values(by='like_count', ascending=True)

top_5_authors = df_sorted['author'].value_counts().head(5)

fig, ax = plt.subplots(figsize=(10, 7))

ax.pie(top_5_authors, labels=top_5_authors.index, autopct="%1.1f%%", startangle=90)

ax.set_title("Top 5 Authors with Most Likes (Ascending Order)")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract the day from the 'published_at' column
df['day'] = pd.to_datetime(df['published_at']).dt.day_name()

# Group the data by day and count the number of comments
comments_by_day = df.groupby('day')['text'].count()

# Create a pie chart
plt.pie(comments_by_day, labels=comments_by_day.index, autopct="%1.1f%%")
plt.title('Comments per Day')
plt.show()

# %%
import matplotlib.pyplot as plt
from textblob import TextBlob

# Create a function to analyze the sentiment of a text
def analyze_sentiment(text):
  analysis = TextBlob(text)
  sentiment = analysis.sentiment.polarity
  return sentiment

# Apply the function to the 'text' column and create a new column 'sentiment'
df['sentiment'] = df['text'].apply(analyze_sentiment)

# Display the head of the DataFrame
df.head()

# Count the number of positive, negative, and neutral comments
positive_comments = df[df['sentiment'] > 0].shape[0]
negative_comments = df[df['sentiment'] < 0].shape[0]
neutral_comments = df[df['sentiment'] == 0].shape[0]

# Create a pie chart to visualize the sentiment distribution
labels = ['Positive', 'Negative', 'Neutral']
sizes = [positive_comments, negative_comments, neutral_comments]
colors = ['green', 'red', 'yellow']

plt.pie(sizes, labels=labels, colors=colors, autopct="%1.1f%%")
plt.title('Sentiment Distribution')
plt.show()

# %%
def analyze_sentiment(text):
  analysis = TextBlob(text)
  sentiment = analysis.sentiment.polarity
  if sentiment > 0:
    return "Positive"
  elif sentiment < 0:
    return "Negative"
  else:
    return "Neutral"

df['Sentiment'] = df['text'].apply(analyze_sentiment)

df.head()
# Out:
#                   author          published_at            updated_at  \
# 0      @deepakambati1659  2024-06-29T07:20:20Z  2024-06-29T07:20:20Z
# 1              @AC-ub7tq  2024-06-27T00:30:35Z  2024-06-27T00:30:35Z
# 2  @justanaveragejoe9416  2024-06-25T21:09:36Z  2024-06-25T21:09:36Z
# 3    @brajeshahirwar8803  2024-06-23T18:34:51Z  2024-06-23T18:34:51Z
# 4              @AK-ms5zk  2024-06-22T16:55:14Z  2024-06-22T16:55:14Z
#
#    like_count                                               text       day  \
# 0           0      Ok but hydrogen can explode what about safety  Saturday
# 1           0              Everything keeps going Right - Toyota  Thursday
# 2           0  It doesn&#39;t matter what type of engine you ...   Tuesday
# 3           0                                  Good job sir ji 👍    Sunday
# 4           0  Electric cars are an unsustainable scam there’...  Saturday
#
#    sentiment Sentiment
# 0   0.500000  Positive
# 1   0.285714  Positive
# 2   0.072288  Positive
# 3   0.700000  Positive
# 4   0.000000   Neutral

# %%
def analyze_sentiment(text):
  analysis = TextBlob(text)
  sentiment = analysis.sentiment.polarity
  if sentiment > 0:
    return "Positive"
  elif sentiment < 0:
    return "Negative"
  else:
    return "Neutral"

# Example usage
text = "This is a wonderful product! I love it!"
sentiment = analyze_sentiment(text)
print(sentiment)  # Output: "Positive"

text = "This product is terrible. I hate it!"
sentiment = analyze_sentiment(text)
print(sentiment)  # Output: "Negative"

text = "This product is okay. It's not great, but it's not bad either."
sentiment = analyze_sentiment(text)
print(sentiment)  # Output: "Neutral"
# Out:
# Positive
# Negative
# Positive

# %%
df['text']
# Out:
# 0         Ok but hydrogen can explode what about safety
# 1                 Everything keeps going Right - Toyota
# 2     It doesn&#39;t matter what type of engine you ...
# 3                                     Good job sir ji 👍
# 4     Electric cars are an unsustainable scam there’...
#                             ...
# 95                                        Go Toyota go.
# 96    the problem with hydrogen is storage. When the...
# 97                                  Toyota is bragging😅
# 98                                                😂😂😮😮😮
# 99    This engine sounds more appropriate for milita...
# Name: text, Length: 100, dtype: object

# %%
# Example usage
text = "   Good job sir ji 👍"
sentiment = analyze_sentiment(text)
print(sentiment)  # Output: "Positive"

text = "Electric cars are an unsustainable scam there’..."
sentiment = analyze_sentiment(text)
print(sentiment)

text = "maybe we should back to ride horses like cowbo...."
sentiment = analyze_sentiment(text)
print(sentiment)  # Output: "Neutral"
# Out:
# Positive
# Neutral
# Neutral

# %%
import matplotlib.pyplot as plt

# Calculate the length of each comment
df['text_length'] = df['text'].str.len()

# Create a bar plot of comment lengths
plt.bar(df.index, df['text_length'])
plt.xlabel('Comment Index')
plt.ylabel('Comment Length')
plt.title('Comment Lengths')
plt.show()

# Create a line plot of comment lengths
plt.plot(df.index, df['text_length'])
plt.xlabel('Comment Index')
plt.ylabel('Comment Length')
plt.title('Comment Lengths')
plt.show()

# %%
# prompt: deploy it using streamlit

# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 37.3 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.4.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 17.1 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 36.5 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.1-py3-none-manylinux2014_x86_64.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: watchdog, smmap, pydeck, gitdb, gitpython, streamlit
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 pydeck-0.9.1 smmap-5.0.1 streamlit-1.36.0 watchdog-4.0.1

# %%
# !pip install streamlit pyngrok
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (1.36.0)
# Collecting pyngrok
#   Downloading pyngrok-7.1.6-py3-none-any.whl (22 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.4.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.0.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.1.6

# %%
! pip install streamlit -q
# !wget -q -O - ipv4.icanhazip.com
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# 34.86.110.122
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.86.110.122:8501
#
# npx: installed 22 in 4.369s
# your url is: https://hot-hoops-bow.loca.lt
#   Stopping...
# ^C

# %%
# %%writefile app.py
# Out:
# Overwriting app.py

# %%
# Step 1: Install Streamlit and nbformat
# !pip install streamlit nbformat
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (1.36.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (5.10.4)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.4.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.0.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat) (4.19.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbformat) (5.7.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat) (0.18.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
# Step 2: Write the Streamlit app to display the notebook

import streamlit as st
import nbformat

# Function to read and display the notebook
def display_notebook(notebook_path):
    with open(notebook_path, 'r', encoding='utf-8') as f:
        notebook_content = nbformat.read(f, as_version=4)

    for cell in notebook_content.cells:
        if cell.cell_type == 'markdown':
            st.markdown(cell.source)
        elif cell.cell_type == 'code':
            st.code(cell.source)
            if 'outputs' in cell:
                for output in cell.outputs:
                    if output.output_type == 'stream':
                        st.text(output.text)
                    elif output.output_type == 'execute_result':
                        st.write(output.data['text/plain'])

# Display the notebook
notebook_path = r"/content/Untitled59.ipynb"
display_notebook(notebook_path)

# %%
! streamlit run app.py
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.86.110.122:8501
